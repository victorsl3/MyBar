# %%
import requests, json 
  
api_key = 'AIzaSyC6m1cxuL4zjSqBglRRD_g7JHbNhJMH3-g'
  
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
  
query = input('Search query: ') 
  
r = requests.get(url + 'query=' + query +
                        '&key=' + api_key) 
  
x = r.json() 
  
y = x['results'] 
  
for i in range(len(y)): 
    print("Resultado",i+1,": \t")
    print("ID: ",y[i]['place_id']) 
    print("Nombre: ",y[i]['name']) 
    print("Coordenadas: ",y[i]['geometry']["location"])
    print("Icono: ",requests.get(y[i]['icon']))
    print("Horas de apertura: ",y[i]['opening_hours'])
    print("Nivel de precio: ",y[i]['price_level'])
    print("Rating: ",y[i]['rating'])
    print("----------------")
# Out:
# Search query:  Restaurante
# Resultado 1 :
# ID:  ChIJAQAApeQoQg0RvAkF6wVRsJQ
# Nombre:  El Enfriador
# Coordenadas:  {'lat': 40.4495926, 'lng': -3.6917691}
# Icono:  <Response [200]>
# Horas de apertura:  {'open_now': True}
# Nivel de precio:  2
# Rating:  4.3
# ----------------
# Resultado 2 :
# ID:  ChIJMa4j0v4oQg0RDsbMl5IaF4g
# Nombre:  Restaurante Bar Rodrigo
# Coordenadas:  {'lat': 40.4488902, 'lng': -3.6998199}
# Icono:  <Response [200]>
# Horas de apertura:  {'open_now': False}
# Nivel de precio:  1
# Rating:  4.5
# ----------------
# Resultado 3 :
# ID:  ChIJTfao2_4oQg0Rbc8CW2Z4Nwg
# Nombre:  Restaurante Os Piñeiros
# Coordenadas:  {'lat': 40.4493312, 'lng': -3.7000161}
# Icono:  <Response [200]>
# Horas de apertura:  {'open_now': False}
# Nivel de precio:  1
# Rating:  4.3
# ----------------
# Resultado 4 :
# ID:  ChIJTa60sf4oQg0RJap9WyDVU_Q
# Nombre:  Bar Restaurante Torrijos
# Coordenadas:  {'lat': 40.449122, 'lng': -3.6985395}
# Icono:  <Response [200]>
# ...
