# %% [markdown]
# # Búsqueda en la API de Google Maps

# %%
import requests as req
from PIL import Image
from io import BytesIO
import json 
import pandas as pd
import numpy as np
api_key = 'AIzaSyAMPRgLpuErhhf6Bcg9OuS6V97GPOLqsjg'

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
  
query = "Bar"
callback="initMap"
  
busqueda = req.get(url + 'query=' + query +'&key=' + api_key + "&callback="+callback)
r=busqueda.json()["results"]

# %% [markdown]
# # Creación del dataframe

# %%
nombre=[]
calle = []
id = []
nivel_precio=[]
calificacion=[]
numero_calificaciones=[]
latitud=[]
longitud=[]
coordenadas=[]
tipo = []
estado=[]
abierto=[]
fotos=[]
for i in range(len(r)):
    
    nombre.append(r[i]['name'])
    
    calle.append(r[i]['formatted_address'])
    
    id.append(r[i]['place_id'])
    
    latitud.append(r[i]['geometry']['location']['lat'])
    
    longitud.append(r[i]['geometry']['location']['lng'])
    
    coordenadas.append([r[i]['geometry']['location']['lat'],r[i]['geometry']['location']['lng']])
    
    tipo.append(r[i]['types'])
    
    estado.append(r[i]['business_status'])
    
    if "price_level" in r[i]:
        nivel_precio.append(r[i]['price_level'])
    else:
        nivel_precio.append(np.nan)
        
    calificacion.append(r[i]['rating'])
    
    numero_calificaciones.append(r[i]['user_ratings_total'])
    
    if "opening_hours" in r[i]:
        abierto.append(r[i]['opening_hours']["open_now"])
    else:
        abierto.append("Desconocido")
    
    if "photos" in r[i]:
        ref=(r[i]["photos"][0]["photo_reference"])
        url_foto="https://maps.googleapis.com/maps/api/place/photo?maxwidth=400"
        busqueda_foto=url_foto+"&photo_reference="+ref+'&key=' + api_key
        fotos.append(busqueda_foto)
    else:
        fotos.append(np.nan)


df = pd.DataFrame(data={
    "nombre":nombre,
    'calle':calle,
    'id_local':id,
    "disponibilidad":abierto,
    "tipo":tipo,
    'coordenadas':coordenadas,
    "longitud":longitud,
    "latitud": latitud,
    "estado":estado,
    "nivel_precio":nivel_precio,
    "calificacion":calificacion,
    "numero_calificaciones":numero_calificaciones,
    "foto":fotos
    })
df["disponibilidad"]=df["disponibilidad"].replace(True, "Abierto")
df["disponibilidad"]=df["disponibilidad"].replace(False, "Cerrado")
df.head()
# Out:
#                 nombre                                              calle  \
# 0       27 Veintisiete    Calle de Diego de León, 27, 28006 Madrid, Spain
# 1      Bar La Escalera    Calle de Diego de León, 34, 28006 Madrid, Spain
# 2  Bar Restaurant Leon    Calle de Diego de León, 40, 28006 Madrid, Spain
# 3             Bar Rafa  Calle de Diego de León, 26, derecha, 28006 Mad...
# 4        El Cuento Bar     Calle de Diego de León, 7, 28006 Madrid, Spain
#
#                       id_local disponibilidad  \
# 0  ChIJr3ARFcAoQg0R96tfmtX4HhY        Abierto
# 1  ChIJqdYIiMAoQg0RB--fUzRT-vU        Abierto
# 2  ChIJQ9-QZMAoQg0R4yG4v3kea_Q        Abierto
# 3  ChIJRdaIHsAoQg0RKGpAs6q8xwE        Abierto
# 4  ChIJyVLq4OooQg0RBLCdJDhhjt0        Cerrado
#
#                                                 tipo  \
# 0  [bar, restaurant, food, point_of_interest, est...
# 1  [bar, restaurant, food, point_of_interest, est...
# 2  [bar, restaurant, food, point_of_interest, est...
# 3            [bar, point_of_interest, establishment]
# 4            [bar, point_of_interest, establishment]
#
#                                coordenadas  longitud    latitud       estado  \
# 0  [40.43509419999999, -3.681447599999999] -3.681448  40.435094  OPERATIONAL
# 1                 [40.4346989, -3.6813463] -3.681346  40.434699  OPERATIONAL
# 2                 [40.4346431, -3.6803853] -3.680385  40.434643  OPERATIONAL
# 3                 [40.4347273, -3.6824829] -3.682483  40.434727  OPERATIONAL
# 4                  [40.435184, -3.6849596] -3.684960  40.435184  OPERATIONAL
#
#    nivel_precio  calificacion  numero_calificaciones  \
# 0           1.0           4.2                    253
# 1           1.0           4.2                    558
# 2           1.0           4.2                    285
# 3           NaN           4.0                      3
# 4           NaN           3.7                    347
#
#                                                 foto
# 0  https://maps.googleapis.com/maps/api/place/pho...
# 1  https://maps.googleapis.com/maps/api/place/pho...
# 2  https://maps.googleapis.com/maps/api/place/pho...
# 3                                                NaN
# 4  https://maps.googleapis.com/maps/api/place/pho...

# %%
calles=[]
cp=[]
for n in df["calle"]:
    direccion=n[0:n.index('Madrid')-8]
    codigo = n[n.index('Madrid')-6:n.index('Madrid')]
    calles.append(direccion)
    cp.append(codigo)
df["calle"]=calles
df['cp']=cp
df.head(5)
# Out:
#                 nombre                                calle  \
# 0       27 Veintisiete           Calle de Diego de León, 27
# 1      Bar La Escalera           Calle de Diego de León, 34
# 2  Bar Restaurant Leon           Calle de Diego de León, 40
# 3             Bar Rafa  Calle de Diego de León, 26, derecha
# 4        El Cuento Bar            Calle de Diego de León, 7
#
#                       id_local disponibilidad  \
# 0  ChIJr3ARFcAoQg0R96tfmtX4HhY        Abierto
# 1  ChIJqdYIiMAoQg0RB--fUzRT-vU        Abierto
# 2  ChIJQ9-QZMAoQg0R4yG4v3kea_Q        Abierto
# 3  ChIJRdaIHsAoQg0RKGpAs6q8xwE        Abierto
# 4  ChIJyVLq4OooQg0RBLCdJDhhjt0        Cerrado
#
#                                                 tipo  \
# 0  [bar, restaurant, food, point_of_interest, est...
# 1  [bar, restaurant, food, point_of_interest, est...
# 2  [bar, restaurant, food, point_of_interest, est...
# 3            [bar, point_of_interest, establishment]
# 4            [bar, point_of_interest, establishment]
#
#                                coordenadas  longitud    latitud       estado  \
# 0  [40.43509419999999, -3.681447599999999] -3.681448  40.435094  OPERATIONAL
# 1                 [40.4346989, -3.6813463] -3.681346  40.434699  OPERATIONAL
# 2                 [40.4346431, -3.6803853] -3.680385  40.434643  OPERATIONAL
# 3                 [40.4347273, -3.6824829] -3.682483  40.434727  OPERATIONAL
# 4                  [40.435184, -3.6849596] -3.684960  40.435184  OPERATIONAL
#
#    nivel_precio  calificacion  numero_calificaciones  \
# 0           1.0           4.2                    253
# 1           1.0           4.2                    558
# 2           1.0           4.2                    285
# 3           NaN           4.0                      3
# 4           NaN           3.7                    347
#
#                                                 foto      cp
# 0  https://maps.googleapis.com/maps/api/place/pho...  28006
# 1  https://maps.googleapis.com/maps/api/place/pho...  28006
# 2  https://maps.googleapis.com/maps/api/place/pho...  28006
# 3                                                NaN  28006
# 4  https://maps.googleapis.com/maps/api/place/pho...  28006

# %%
n="C. de Ponzano, 24, 28003 Madrid, Spain"
direccion=n[0:n.index('Madrid')]
direccion
# Out:
# 'C. de Ponzano, 24, 28003 '

# %%
df.to_csv("muestra.csv")

# %% [markdown]
# df.to_csv("peatones_procesado_procesado.csv")# Mapas

# %%
import folium

m=folium.Map(
    location=df.iloc[0].coordenadas,
    tiles="Stamen Terrain",
    zoom_start=15
)

for i in range(0,len(df["coordenadas"])):
    tooltip = df["nombre"][i]
    popup=df["nombre"][i]+"\t"+df["disponibilidad"][i]+"\t Calificación:"+str(df["calificacion"][i])
    folium.Marker(df["coordenadas"][i], popup=popup, tooltip=tooltip).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_05d611559fe34c669d7f5796d3153521%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_05d611559fe34c669d7f5796d3153521%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_05d611559fe34c669d7f5796d3153521%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_05d611559fe34c669d7f5796d3153521%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.43509419999999%2C%20-3.681447599999999%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# # Mostrar fotos

# %%
def getFoto(foto_enlace):
    foto_bytes=req.get(foto_enlace).content
    return(Image.open(BytesIO(foto_bytes)))

# %%
getFoto(df.iloc[0].foto)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x300 at 0x271D89DCDC0>

# %% [markdown]
# # BBDD

# %%
import mysql.connector
conexion1=mysql.connector.connect(host="localhost", 
                                  user="root", 
                                  passwd="", 
                                  database="mydb")
cursor1=conexion1.cursor()
cursor1.execute("show tables")
for tabla in cursor1:
    print(tabla)
# Out:
# ('consulta',)
# ('local',)
# ('local consultado',)
# ('local consultado predecido',)
# ('lugares',)
# ('predicciones',)
# ('usuario',)

# %% [markdown]
# ## Tabla Local

# %% [markdown]
# Modificamos algunos tipos

# %%
sql="ALTER TABLE local MODIFY Calle text"
cursor1.execute(sql)
sql="ALTER TABLE local MODIFY Foto text"
cursor1.execute(sql)
sql="ALTER TABLE local MODIFY tipo text"
cursor1.execute(sql)
conexion1.commit()
conexion1.close()

# %% [markdown]
# Limpiamos los nulos

# %%
df.isna().any()
# Out:
# nombre                   False
# calle                    False
# id_local                 False
# disponibilidad           False
# tipo                     False
# coordenadas              False
# longitud                 False
# latitud                  False
# estado                   False
# nivel_precio              True
# calificacion             False
# numero_calificaciones    False
# foto                      True
# cp                       False
# dtype: bool

# %%
df["nivel_precio"]=df.nivel_precio.fillna(0)
df["foto"]=df.foto.fillna("Inexistente")

# %% [markdown]
# Convertimos en matriz

# %%
nmp=df.to_records()
nmp[0][13]
for n in range (14):
    n=n+1
    print(nmp[1][n])
# Out:
# Bar La Escalera
# Calle de Diego de León, 34
# ChIJqdYIiMAoQg0RB--fUzRT-vU
# Abierto
# ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment']
# [40.4346989, -3.6813463]
# -3.6813463
# 40.4346989
# OPERATIONAL
# 1.0
# 4.2
# 558
# https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photo_reference=Aap_uECAXqlKY3Ktiq1vebjPbvMQ1p5z_NPvVnj2RH3jUAOo6RCHQk-5bTGSsFxIH_eVjwii_TtVZ4LIqDy6KZLJp4Ie6ZzMviIP08mbNUIiLGhjpl3kkg3kFpOceorEDUU9ZyqsmDpN8PU0hAWMkPDL7fFo_sfuc_BmSC5cIUByuyE-bDDT&key=AIzaSyAMPRgLpuErhhf6Bcg9OuS6V97GPOLqsjg
# 28006

# %% [markdown]
# ### Inserción

# %%
conexion1=mysql.connector.connect(host="localhost", 
                                  user="root", 
                                  passwd="", 
                                  database="mydb")
cursor1=conexion1.cursor()
for n in range(19):
    n=n+1
    sql="replace into local(idLocal, Calle, Nombre, Tipo, Longitud, Latitud,Foto,CP) values (%s,%s,%s,%s,%s,%s,%s,%s)"
    tipos=""
    for i in nmp[n][5]:
        tipos=tipos+i+", "
    tipos= tipos[0:-2]
    insercion=(nmp[n][3],nmp[n][2],nmp[n][1],tipos,float(nmp[n][7]),float(nmp[n][8]),nmp[n][13],nmp[n][14])
    cursor1.execute(sql, insercion)
    conexion1.commit()
conexion1.close()

# %% [markdown]
# ### Extracción

# %%
conexion1=mysql.connector.connect(host="localhost", 
                                  user="root", 
                                  passwd="", 
                                  database="mydb")
cursor1=conexion1.cursor()
sql="select * from local"
cursor1.execute(sql)
myresult = cursor1.fetchall()

for x in myresult:
  print(x)
# Out:
# ('ChIJ32u0l-ooQg0R0mrjaBXfD8s', 'Bò Finn Sports Bar', 'C. de Velázquez, 97', 'bar, restaurant, food, point_of_interest, establishment', -3.6835478, 40.4351233, 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photo_reference=Aap_uEAT4_Uo1ihJ-dq_JIGXH5mNMEl-jZHS1pfwXZEBX59kYcpDxr4yq9zjpclvvI886pqBnEmLYZE4lOhC6iXd7b_Ol1zULSuZYfWWfICm49EppWeX5_Jw2gE5Vl21B0WiECmKPvQv-qnv-55E7AOJKwbPjxB7IYDxjEBX6kFmzPITIROZ&key=AIzaSyAMPRgLpuErhhf6Bcg9OuS6V97GPOLqsjg', 28006)
# ('ChIJ6zDwtYgoQg0RfyrlCcpNMMo', 'Areia', 'C. de Hortaleza, 92', 'bar, restaurant, food, point_of_interest, establishment', -3.698024699999999, 40.4245443, 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photo_reference=Aap_uEBpGoaeoAZWvzReRs1OeIy45_VNGxdVGX_ceIN8DfqnG-0ifUyIGPdOyVCJJT1SHJKbSNK8kieEVir_Ak_5SMmRyIho7HRvbhXc05sV5mYesjSccKQu0rHzigv1ZcslULlPQtQTdjE7kzHOWkMpjxhN8oNw9IAhLBi_LgbbHOLqNbbZ&key=AIzaSyAMPRgLpuErhhf6Bcg9OuS6V97GPOLqsjg', 28004)
# ('ChIJ9Y5bOJUoQg0RI3YPBMdC2PQ', 'Milford Bar Restaurante', 'Calle de Juan Bravo, 7', 'bar, restaurant, food, point_of_interest, establishment', -3.683992699999999, 40.43301779999999, 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photo_reference=Aap_uEBzBgDH76LUEwP9ghBCvOd0QJGJYV5j3Vs3wGwpNfqlVl28t00TCoaAuVo99aIwQ-UO2JmlnNO-YrYxDSOUNgUxlkJAh_uta1WiKhaDQWtONV5GLj-zlCCvTucW3NwPtC6oaP0a3exLkJ1ZJzp5SQheYcvMpPjv5CQ_BeMVKkJx8F3t&key=AIzaSyAMPRgLpuErhhf6Bcg9OuS6V97GPOLqsjg', 28006)
# ('ChIJCWFtl_YpQg0R1BryL0B2USo', 'SunBar Madrid', 'Calle de María de Molina, 25', 'bar, point_of_interest, establishment', -3.6838808, 40.437881, 'https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photo_reference=Aap_
://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photo_reference=Aap_uECXDNNknY-nL3p5Ul-nSVTEcbEYsT6sAGfDEbYPPhXijRdKh0QsMf9k16uQpFgbdgm-EIVNS6X9UIDU6QQKVCgr8V1TFiPc-DFiIkCbS88GsOc9Ddo9LSs4GcAJaN3Cjh3ZXZgP-n1n7dx8SoOA6h2APIBg-WnQZuQaRMEB1G4RYBJw&key=AIzaSyAMPRgLpuErhhf6Bcg9OuS6V97GPOLqsjg', 28004)

# %% [markdown]
# ### Extracción en un código postal

# %%
conexion1=mysql.connector.connect(host="localhost", 
                                  user="root", 
                                  passwd="", 
                                  database="mydb")
cursor1=conexion1.cursor()
sql="select * from local where CP=28670"
cursor1.execute(sql)
myresult = cursor1.fetchall()

for x in myresult:
  print(x)

# %% [markdown]
# ## Prediccion

# %%
datos = pd.read_csv('PEATONES_2021.csv', sep=';')
datos = datos.dropna()

# %% [markdown]
# ### Preparación de los datos

# %%
datos['FECHA'] = datos['FECHA'].replace("-","/")
datos['FECHA']= datos['FECHA'].str.slice(0, 10)
datos["FECHA"]
# Out:
# 0        01/01/2021
# 1        01/01/2021
# 2        01/01/2021
# 3        01/01/2021
# 4        01/01/2021
#             ...
# 82531    30/06/2021
# 82532    30/06/2021
# 82533    30/06/2021
# 82534    30/06/2021
# 82535    30/06/2021
# Name: FECHA, Length: 82536, dtype: object

# %%
url = "https://holydayapi.herokuapp.com/"
ciudad="/holidays/city/Madrid"
año_2021="/year/2021/holidays/city/Madrid"
busqueda_2021 = req.get(url + ciudad+año_2021)

festivos=[]

busqueda_2021.json()
for n in r:
    festivos.append(n["day"])
    
festivos.append('31/12/2019')
festivos.append('31/12/2020')
festivos.append('31/12/2021')
festivos.append('31/10/2019')
festivos.append('31/10/2020')
festivos.append('31/10/2021')
festivos
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8376/2984277936.py in <module>
#       6 festivos=[]
#       7
# ----> 8 busqueda_2021.json()
#       9 for n in r:
#      10     festivos.append(n["day"])
#
# ~\anaconda3\envs\pyrebase\lib\site-packages\requests\models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~\anaconda3\envs\pyrebase\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\envs\pyrebase\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\envs\pyrebase\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
festividades=[]
for n in datos['FECHA']:
    if n in festivos:
        festividades.append(True)
    else:
        festividades.append(False)
datos["FESTIVO"]=festividades

# %%
datos.head()

# %%
datos['FECHA']=datos['FECHA']+" "+datos['HORA']

# %%
datos['FECHA'] = pd.to_datetime(datos['FECHA'], format="%d/%m/%Y %H:%M")

# %% [markdown]
# ## Tabla Lugares

# %%
import locale
locale.setlocale(locale.LC_NUMERIC,"es_ES.utf8")

# %%
nombre=[]
distrito=[]
cp=[]
observaciones=[]
latitud=[]
longitud=[]
for n in range(len(datos["IDENTIFICADOR"].unique())):
    nombre.append(datos.groupby("IDENTIFICADOR").NOMBRE_VIAL.unique()[n][0])
    distrito.append(datos.groupby("IDENTIFICADOR").DISTRITO.unique()[n][0])
    cp.append(datos.groupby("IDENTIFICADOR")["CÓDIGO_POSTAL"].unique()[n][0])
    observaciones.append(datos.groupby("IDENTIFICADOR").OBSERVACIONES_DIRECCION.unique()[n][0])
    latitud.append(locale.atof(datos.groupby("IDENTIFICADOR").LATITUD.unique()[n][0]))
    longitud.append(locale.atof(datos.groupby("IDENTIFICADOR").LONGITUD.unique()[n][0]))

# %% [markdown]
# Formato de los decimales

# %% [markdown]
# ### Inserción

# %%
conexion1=mysql.connector.connect(host="localhost", 
                                  user="root", 
                                  passwd="", 
                                  database="mydb")
cursor1=conexion1.cursor()
for n in range(len(datos["IDENTIFICADOR"].unique())):
    sql="replace into lugares(id_lugar, Nombre, Distrito, CP, Observaciones, Latitud, Longitud) values (%s,%s,%s,%s,%s,%s,%s)"
    insercion=(datos["IDENTIFICADOR"].unique()[n],nombre[n],distrito[n],int(cp[n]),observaciones[n],float(latitud[n]),float(longitud[n]))
    cursor1.execute(sql, insercion)
    conexion1.commit()
conexion1.close()

# %% [markdown]
# ### Extracción

# %%
conexion1=mysql.connector.connect(host="localhost", 
                                  user="root", 
                                  passwd="", 
                                  database="mydb")
cursor1=conexion1.cursor()
sql="select * from lugares where observaciones='Acera Pares'"
cursor1.execute(sql)
myresult = cursor1.fetchall()

for x in myresult:
  print(x)

# %% [markdown]
# ## Tabla Predicciones

# %%
lugares=datos.IDENTIFICADOR.tolist()
fechas=datos.FECHA.tolist()
#festivos=datos.FESTIVO.tolist()
peatones=datos.PEATONES.tolist()
identificadores=datos.IDENTIFICADOR.tolist()

# %% [markdown]
# ### Inserción

# %% [markdown]
# conexion1=mysql.connector.connect(host="localhost",
#                                   user="root",
#                                   passwd="",
#                                   database="mydb")
# cursor1=conexion1.cursor()
# for n in range(len(datos["IDENTIFICADOR"])):
#     sql="replace into predicciones(Fecha, id_lugar, peatones) values (%s,%s,%s,%s)"
#     insercion=(str(fechas[n]),identificadores[n],float(peatones[n]))#festivos no esta
#     cursor1.execute(sql, insercion)
#     conexion1.commit()
#
# conexion1.close()

# %% [markdown]
# ### Extracción

# %%
conexion1=mysql.connector.connect(host="localhost", 
                                  user="root", 
                                  passwd="", 
                                  database="mydb")
cursor1=conexion1.cursor()
sql="select * from predicciones where fecha='2021-06-26 00:00:00'"
cursor1.execute(sql)
myresult = cursor1.fetchall()

for x in myresult:
  print(x)

# %% [markdown]
# ## Tabla Consultas

# %% [markdown]
# ### Usuario

# %%
email=input("Introduzca su correo: ")

conexion1=mysql.connector.connect(host="localhost", 
                                  user="root", 
                                  passwd="", 
                                  database="mydb")
cursor1=conexion1.cursor()
sql="select idUsuario from usuario where email="+"'"+email+"'"
cursor1.execute(sql)
myresult = cursor1.fetchall()
id=myresult[0][0]
id
#victorsalvadorlopezz@gmail.com
# Out:
# Introduzca su correo:  victorsalvadorlopezz@gmail.com
# 24

# %%
# importing geopy library
from geopy.geocoders import Nominatim
 
# calling the Nominatim tool
loc = Nominatim(user_agent="GetLoc")
 
# entering the location name
getLoc = loc.geocode(input("Introduzca su ciudad: "))

# printing latitude and longitude
lat=getLoc.latitude
long=getLoc.longitude)
# Out:
# Introduzca su ciudad:  Madrid
# Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, España
# Latitude =  40.4167047
#
# Longitude =  -3.7035825
